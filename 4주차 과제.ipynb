# %% [markdown]
# <a href="https://colab.research.google.com/github/kimyou1102/-assignment/blob/master/4%EC%A3%BC%EC%B0%A8%20%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4주차 과제
# - 용어 정리
# - 딥러닝 강의 클론 코딩
# - 딥러닝 순전파 & 역전파 계산

# %% [markdown]
# ## 1. 용어 정리
#
# 다음 제시된 단어의 정의(설명)를 정리하여 작성 하세요.
#
# * 2문장 이상 작성 해 주세요.
# * 주제(단어)와 크게 벗어나지만 않는다면 정답처리 됩니다.
# * 강의 뿐 아니라 기타 레퍼런스를 참고하여 작성하셔도 됩니다. (기타 레퍼런스를 참고하신 경우, 해당 레퍼런스를 정리하여 하단에 작성해 주세요.)

# %% [markdown]
# __(예시)__
# ### 심층 신경망
# : 입력층과 출력층 사이에 여러 개의 은닉층들로 이뤄진 인공신경망이다. 심층 신경망은 일반적으로 인공신경망과 마찬가지로 복잡한 비선형 관계들을 모델링 할 수 있다. 신층신경망의 목적은 분류 및 수치예측을 하기 위함이고 이미지 트레이닝이나 문자인식과 같은 분야에서 매우 유용하게 쓰이고 있다.

# %% [markdown]
# ### MCP 뉴런
# : MCP는 McCulloch Pitts의 약자로 1943년 워랜 맥컬록과 월터 피츠가 처음으로 간소화된 뇌의 뉴런 개념을 발표했다. 뉴런들의 뇌의 신경세포와 서로 연결되어 있으며 화학적, 전기적 신호를 처리하는데 관여한다. 맥과 피츠는 이러한 신경세포를 이진 출력을 내는 간단한 논리 회로를 표현했다. 1957년 프랭크 로센 블랫이 발표한 퍼셉트론 학습 개념의 기반이 되기도 했다.
#
# ### 퍼셉트론
# : 여러개의 입력을 받아 각각의 값에 가중치를 곱한 후, 모두 더한 것이 출력되는 형태이다. 아주 단순하기 때문에 실제사용은 거의 하지 않는다. 퍼셉트론은 선형 분리 불가능 문제 즉, 선형적으로 구분 되지 않는 데엍 셋에서 수렴하지 않는다.
# 퍼셉트론을 잘 이해하는 방법은 AND,OR,XOR 문제를 풀어보는 것이다. 하지만 XOR문제는 결괏값이 원하는 값으로 수렴하지 않았다. 이를 해결하기 위해 다층퍼셉트론을 제시했다. 은닉층을 활용하게 되면, 선형 분류 판별선을 여러개 그리는 효과를 얻음으로써 문제를 해결이 가능하다. 하지만 다층 퍼셉트론에도 치명적인 약점이 있는데 파라미터 개수가 많아지면서 적절한 가중치와 편향 학습이 어렵다는 거였지만 제프리 힌튼이 역전파 알고리즘을 제시하며 문제를 해결하게 됐다.
#
# ### 역전파
# : 역전파는 출력값과 지도 데이터 사이에 생기는 오차를 이용해 출력층에서 입력층쪽으로 가중치를 조정하는 것이다. 이러한 역전파는 경사 하강법을 사용하는 것이기도 하다. 역전파는 손실 함수가 최솟값일 때의 가중치로 원래의 가중치를 조정해야 한다. 이러한 역전파기법의 문제는 기울기 소멸의 문제가 있다. 이러한 문제를 해결하기 위해 제프리힌턴은 다양한 활성화 함수를 제시 하였는데 그 중 ReLU함수 활용시 어느정도 문제가 해결됨을 발견했다.
#
# ### 강화학습
# : 머신러닝의 분류 중  하나이다. 강화확습은 지도학습처럼 정답이 있지도 않고 비지도학습처럼 데이터만을 기반으로 학습 하지도 않는다. 강화학습의 피드백은 정답 레이블 혹은 수치가 아니다. 강화학습은 에이전트라는 존재가 환경과 상호작용하며, 이 환경에는 보상이라는 기준이 있어서 다양한 시행착오를 겪어가며 보상을 최대화하는 방향으로 학습을 진행한다.
#
# ### 과적합
# : 기계 학습에서 데이터에 대한 학습이 너무 많이 수행되는 현상으로, 학습 대상 데이터에 대한 오차는 감소하지만, 실제 사례에 적용할 경우 오차가 증가하는 문제를 수반한다.(네이버 영어사전 참조) 결정 트리 학습에서 분할 작업을 계속해서 반복하다보면 계속해서 깊은 트리를 생성하면 과적합을 일으킬 수도 있다. 과적합을 방지하기 위해 트리최대 깊이를 제한하여 트리를 가지치기 하는 방법이 있다.
#
# ### 차원의 저주
# : 차원이 증가하면 그 데이터 공간이 커지기 때문에 이를 채우기 위한 데이터 건수도 증가하게 된다. 고정된 크기의 훈련 데이터셋 차원이 늘어남에 따라 특성 공간이 점점 희소해 지는 현상이다.수집된 데이터 건수는 동일하더라도 차원이 증가하면, 즉 변수가 늘어나면 데이터 공간을 채우는 비율이 줄어들기 때문에 변수가 많아질 수록 분석에 요구되는 데이터 건수도 증가한다.
# 차원의 저주를 피하기 위해서 올바른 변수의 선택과 차원 축소의 기법을 사용하면 된다. 변수의 수가 늘어나 차원이 커지면서 발생하는 문제를 차원의 저주라고 한다.
# (참조:https://kkokkilkon.tistory.com/127)

# %% [markdown]
# ## 2. 딥러닝 강의 클론 코딩
#
# ####__퍼셉트론 구조 구현하기__
# 딥러닝 강의(__딥러닝 원리[1] 3:15 ~ 5:15 부분__)를 보고 코드를 따라 치며 출력 결과를 만드세요.
#
#
# * 하나의 코드셀에 해당 코드를 한번에 다 적어서 실행해주세요 (__그렇게 하지 않을 경우, 아래 이미지와 같은 출력값이 나오지 않을 수 있습니다__)
#
# *__주의!__ 실제로 코딩해서 출력해보면 강의에 나온 출력 결과와 다르게 나옵니다!!

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2F0cceeed0-0235-4b0f-af88-0b8c377d5b4b%2F_2020-06-09__9.35.23.png?table=block&id=88fd8912-9356-49a4-9fda-a1a63fe96ea9&width=2870&cache=v2)

# %%
import tensorflow as tf
tf.compat.v1.set_random_seed(2020)
x = 1
y = 0
w = tf.random.normal([1],0,1)

import math
def sigmoid(x):
  return 1/(1+math.exp(-x))

output = sigmoid(x * w)
print(output)

for i in range(1000):
  output = sigmoid(x * w)
  error = y - output
  w = w + x * 0.1 * error

  if i % 100 == 99:
    print("학습횟수:", i ,"ERROR:", error, "예측결과:", output)
# Out:
# 0.47477188589261
# 학습횟수: 99 ERROR: -0.10010598284299604 예측결과: 0.10010598284299604
# 학습횟수: 199 ERROR: -0.05178399422833116 예측결과: 0.05178399422833116
# 학습횟수: 299 ERROR: -0.034590451977903586 예측결과: 0.034590451977903586
# 학습횟수: 399 ERROR: -0.02588962752851373 예측결과: 0.02588962752851373
# 학습횟수: 499 ERROR: -0.020658699939863617 예측결과: 0.020658699939863617
# 학습횟수: 599 ERROR: -0.017174253993457355 예측결과: 0.017174253993457355
# 학습횟수: 699 ERROR: -0.014689506449480992 예측결과: 0.014689506449480992
# 학습횟수: 799 ERROR: -0.012829497265431342 예측결과: 0.012829497265431342
# 학습횟수: 899 ERROR: -0.011385568271837804 예측결과: 0.011385568271837804
# 학습횟수: 999 ERROR: -0.010232493309882492 예측결과: 0.010232493309882492

# %% [markdown]
# ## 3. 딥러닝 순전파 & 역전파 계산
#
# 딥러닝 강의(__딥러닝 원리[2] 0:55 ~ 4:32 부분__)에 나오는 순전파 & 역전파 계산에 대한 문제 입니다.
#
# 해당 영상과 다음 이미지를 참고하여 다음 2가지 물음에 답하세요.
#
#
# (1) 학습률이 0.2 일 경우 출력층의 노드값
#
# (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은?

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Ff54dfd45-92ec-44ae-9616-6949d2484a45%2F_2020-06-10__5.22.03.png?table=block&id=ee05da89-3ceb-4ad9-a2d3-c9f68d24d1d9&width=3580&cache=v2)

# %% [markdown]
# ## (1) 학습률이 0.2 일 경우 출력층의 노드값 : 1.6
# ## (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은?:  0.1
